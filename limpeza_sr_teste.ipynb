# %%
import pandas as pd
import numpy as np

# FEITO!!!

# %%
df_ariba_sr = pd.read_csv('Projeto_de_Sourcing.csv', sep=',', encoding='latin1')
df_ariba_sr.head()
# Out:
#   [PSO]Projeto (CÃ³digo do projeto) [PSO]Data inicial (Data)  \
# 0                      WS4044237018                 7/6/2023
# 1                      WS4426334380                 2/2/2024
# 2                      WS4266890182               19/10/2023
# 3                      WS4222132204                20/9/2023
# 4                      WS4472281001                 4/3/2024
#
#   [PSO]Data final (Data) [PSO] Area do comprador  \
# 0              22/6/2023      Devices Purchasing
# 1               2/2/2024      Devices Purchasing
# 2             20/10/2023      Devices Purchasing
# 3              22/9/2023      Devices Purchasing
# 4               7/3/2024      Devices Purchasing
#
#            [PSO] Unidade organizacional do comprador  \
# 0  Business Support Officer - Purchasing - Commer...
# 1  Business Support Officer - Purchasing - Commer...
# 2  Business Support Officer - Purchasing - Commer...
# 3  Business Support Officer - Purchasing - Commer...
# ...
